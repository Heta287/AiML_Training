# %% [markdown]
# ## AI/ML Session 1 - 26th August 2024
# ### By - Heta Rahul Patel

# %% [markdown]
# ---

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Simulating the Restaurant Sales Data

# %%
# We will create a dataset with sales of dishes for each day of the week.
data = {
    'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
    'Pasta': np.random.randint(10, 50, size=7),
    'Pizza': np.random.randint(20, 60, size=7),
    'Burger': np.random.randint(15, 55, size=7),
    'Salad': np.random.randint(5, 30, size=7),
    'Noodles': np.random.randint(10, 40, size=7)
}

df = pd.DataFrame(data)
print("Restaurant Sales Data")
print(df)
# Out:
# Restaurant Sales Data
#          Day  Pasta  Pizza  Burger  Salad  Noodles
# 0     Monday     30     47      44     16       34
# 1    Tuesday     15     26      33     20       20
# 2  Wednesday     23     22      15     11       12
# 3   Thursday     17     49      15      6       34
# 4     Friday     41     47      47     18       34
# 5   Saturday     49     27      16     16       20
# 6     Sunday     41     44      50     16       36

# %%
# Save the above created dataframe as a csv file (remove the '#' from the start of the next line to uncomment)
# df.to_csv('filepath.csv', index=False)

# %% [markdown]
# ## Understanding the Data with Pandas

# %%
# Load and read a csv file as a dataframe (remove the '#' from the start of the next line to uncomment)
# df = pd.read_csv('filepath.csv')

# %%
# Viewing basic information about the dataset
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Day      7 non-null      object
#  1   Pasta    7 non-null      int64
#  2   Pizza    7 non-null      int64
#  3   Burger   7 non-null      int64
#  4   Salad    7 non-null      int64
#  5   Noodles  7 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 464.0+ bytes

# %%
# Summary statistics of the dataset
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#            Pasta      Pizza     Burger      Salad    Noodles
# count   7.000000   7.000000   7.000000   7.000000   7.000000
# mean   30.857143  37.428571  31.428571  14.714286  27.142857
# std    13.171036  11.816050  15.946339   4.715728   9.581729
# min    15.000000  22.000000  15.000000   6.000000  12.000000
# 25%    20.000000  26.500000  15.500000  13.500000  20.000000
# 50%    30.000000  44.000000  33.000000  16.000000  34.000000
# 75%    41.000000  47.000000  45.500000  17.000000  34.000000
# max    49.000000  49.000000  50.000000  20.000000  36.000000

# %%
# Accessing columns
print("\nSales of Pasta:")
print(df['Pasta'])
# Out:
# Sales of Pasta:
# 0    30
# 1    15
# 2    23
# 3    17
# 4    41
# 5    49
# 6    41
# Name: Pasta, dtype: int64

# %%
# Filtering data: What were the sales on Saturday?
print("\nSaturday's Sales:")
print(df[df['Day'] == 'Saturday'])
# Out:
# Saturday's Sales:
#         Day  Pasta  Pizza  Burger  Salad  Noodles
# 5  Saturday     49     27      16     16       20

# %%
# Adding a Total Sales column
df['Total Sales'] = df[['Pasta', 'Pizza', 'Burger', 'Salad', 'Noodles']].sum(axis=1)
print("\nData with Total Sales Column:")
print(df)
# Out:
# Data with Total Sales Column:
#          Day  Pasta  Pizza  Burger  Salad  Noodles  Total Sales
# 0     Monday     30     47      44     16       34          171
# 1    Tuesday     15     26      33     20       20          114
# 2  Wednesday     23     22      15     11       12           83
# 3   Thursday     17     49      15      6       34          121
# 4     Friday     41     47      47     18       34          187
# 5   Saturday     49     27      16     16       20          128
# 6     Sunday     41     44      50     16       36          187

# %% [markdown]
# ## Using Numpy for Analysis

# %%
# Calculate the average sales of each dish over the week
average_sales = np.mean(df[['Pasta', 'Pizza', 'Burger', 'Salad', 'Noodles']].values, axis=0)
print("\nAverage Sales of Each Dish Over the Week:")
print("Pasta: ", average_sales[0])
print("Pizza: ", average_sales[1])
print("Burger: ", average_sales[2])
print("Salad: ", average_sales[3])
print("Noodles: ", average_sales[4])
# Out:
# Average Sales of Each Dish Over the Week:
# Pasta:  30.857142857142858
# Pizza:  37.42857142857143
# Burger:  31.428571428571427
# Salad:  14.714285714285714
# Noodles:  27.142857142857142

# %%
# Maximum and Minimum Sales
max_sales = np.max(df['Total Sales'])
min_sales = np.min(df['Total Sales'])
print("\nMax Sales in a Day: ", max_sales)
print("Min Sales in a Day: ", min_sales)
# Out:
# Max Sales in a Day:  187
# Min Sales in a Day:  83

# %% [markdown]
# ## Visualizing Data with Matplotlib

# %%
# Plotting the sales of each dish across the days of the week
plt.figure(figsize=(10, 6))
for dish in ['Pasta', 'Pizza', 'Burger', 'Salad', 'Noodles']:
    plt.plot(df['Day'], df[dish], marker='o', label=dish)

plt.title("Daily Sales of Dishes")
plt.xlabel("Day of the Week")
plt.ylabel("Number of Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Bar Plot: Comparing Total Sales for Each Day
plt.figure(figsize=(8, 5))
plt.bar(df['Day'], df['Total Sales'], color='skyblue')
plt.title("Total Sales per Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Sales")
plt.show()

# %%
# Pie Chart: Distribution of Sales Among Different Dishes Over the Week
total_dish_sales = df[['Pasta', 'Pizza', 'Burger', 'Salad', 'Noodles']].sum().values
labels = ['Pasta', 'Pizza', 'Burger', 'Salad', 'Noodles']

plt.figure(figsize=(7, 7))
plt.pie(total_dish_sales, labels=labels, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])
plt.title("Proportion of Sales by Dish Over the Week")
plt.show()

# %%
# Moving Average with Pandas for Trend Analysis
df['7-Day Moving Average'] = df['Total Sales'].rolling(window=7).mean()
plt.figure(figsize=(10, 6))
plt.plot(df['Day'], df['Total Sales'], label='Total Sales', marker='o')
plt.plot(df['Day'], df['7-Day Moving Average'], label='7-Day Moving Average', linestyle='--')
plt.title("Sales Trend with Moving Average")
plt.xlabel("Day of the Week")
plt.ylabel("Total Sales")
plt.legend()
plt.show()
